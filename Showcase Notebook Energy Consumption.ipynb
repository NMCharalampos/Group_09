# %%
import os
from typing import List
import matplotlib
from matplotlib import pyplot as plt
import matplotlib.ticker as mtick
import requests
import pandas as pd
import seaborn as sns
import numpy as np

DATA_URL = "https://raw.githubusercontent.com/owid/energy-data/master/owid-energy-data.csv"
DIRECTORY = os.path.join('downloads', 'Consumption.csv')

# %%
import data_handler as dh

item = dh.DataHandler()
item.load_data()
# Out:
# read data ...
# /Users/niklaskolloge/Documents/projects/Group_9/data_handler.py:58: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   self.data = self.data.drop('renewables_consumption', 1)

# %%
item.gap_minder(1970)
item.gap_minder(2000)
item.gap_minder(2015)

# %% [markdown]
# The three plots clearly show, that the overall word’s energy consumption as well as GDP has gone up over the recent years. For countries in the lower end, it looks like there GDP has slightly increased while energy consumption remained roughly the same. On the right end, on the other hand, high economic development stands in conjunction with increased energy consumption. In order to get a more detailed view on the general GDP, energy as well as population development, a color scale representing continents instead of countries as well as an exclusion of the big „World bubble“ would be helpful. We will try to address that in the second part of the assignment.

# %%
item.plot_consumption("Germany")
item.plot_consumption("India")
item.plot_consumption("China")
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ##### TO-DO: Adjust axes for "plot_consumption" --> years (x) and relative consumption (y)

# %% [markdown]
# Looking at the three plots, it is clearly evident that the total energy consumption of India and China vastly increased over the years corresponding to their strong development. This is backed by coal and fossil fuels as the main energy providers. In comparison, the overall energy consumption remained rather constant for Germany. While it is still highly reliant on coal and fossil fuels, the share of gas and low carbon has slightly increased over the years. The EU carbon tax is likely one of the reasons for this; however current efforts are certainly not enough to meet the goal of 1.5 degrees by 2030, and neither net-zero by 2050.

# %%
item.compare_consumption("Germany", "India", "China")

# %% [markdown]
# Overall, Germany and India both show a similar consumption pattern in absolute and relative terms today. It also becomes evident that India still strongly relies on coal consumption whereas Germany is also increasingly relying on gas. For both countries fossil fuels still present the number one energy supplier. Looking at China, the relative consumption amounts seem to be somehow similar to India whereas its absolute consumption skyrockets in comparison to both - India and Germany. This corresponds to the fact that it is the country with the highest population while simultaneously being the number one greenhouse emissioner.

# %%
item.gdp("Germany", "India", "China")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/x2/hf5692tn1zv14v9vw916q6rm0000gn/T/ipykernel_28800/4234384103.py in <module>
# ----> 1 item.gdp(["Germany", "India", "China"])
#
# ~/Documents/projects/Group_9/data_handler.py in gdp(self, *countries)
#     138         for country in countries:
#     139             if not self.is_country(country):
# --> 140                 return ValueError("Country " + country + " does not exist.")
#     141             df_gdp = self.data.loc[self.data["country"] == country][['country','gdp','year']]
#     142             plt.plot(df_gdp['year'],df_gdp['gdp'], label = country)
#
# TypeError: can only concatenate str (not "list") to str

# %% [markdown]
# The plot shows that the GDP of all countries has risen since 1970. However, there are clear differences in the steepness of the curves. Germany shows a rather constant increase. While it had the highest GDP back in the 1970s, it has been overtaken by China around 1980 as well as by India in the 2000s. This corresponds to the huge developments of the Indian and Chinese economy over the recent years whereas Germany could already been considered to be so. However, as especially apparent when looking at China in both plots - economic development also leads to an extreme increase of energy consumption which is currently majorly carried by non-sustainable energy sources.

# %% [markdown]
# ##### To-Do: Develop gap minder plot method to show GDP, consumption and population for selected countries only.
